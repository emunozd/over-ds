# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from google.colab import drive
drive.mount('/content/drive')

import requests
from bs4 import BeautifulSoup

# Función para scrapear los datos de la tabla y agregar el tier correspondiente
def scrape_tier_data(tier):
    # URL de la página web con el parámetro skillTier
    url = f'https://www.overbuff.com/rankings?platform=pc&gameMode=competitive&hero=ana&season=ow2s11&skillTier={tier}'

    # Realizar una solicitud GET a la URL
    response = requests.get(url, headers = {'User-agent': 'your bot 0.1'})

    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table', class_='w-full whitespace-nowrap')
    rows = table.find_all('tr')
    data = []

    for row in rows:
      # Encuentra todos los 'td' de la fila
      cells = row.find_all('td')
      if len(cells) > 1:  # Asegúrate de que haya al menos dos columnas
          # Obtén el texto del segundo 'td'
          player_with_tier = cells[1].get_text(strip=True)
          # Capitaliza el 'tier' y ajusta el nombre del jugador
          capitalized_tier = tier.capitalize()
          if player_with_tier.endswith(capitalized_tier):
              player_name = player_with_tier[:-len(capitalized_tier)].strip()
          else:
              player_name = player_with_tier
          # Reemplaza el nombre del jugador en la lista y añade el tier
          row_data = [player_name, capitalized_tier]
          data.append(row_data)
    return data

def get_player_data(player):
  intentos=0
  continuar=True
  nick, number = player.split('#')
  data=None
  while intentos < 3 and continuar :
    api_url = f'https://overfast-api.tekrop.fr/players/{nick}-{number}'
    response = requests.get(api_url, headers = {'User-agent': 'your bot 0.1'})
    if response.status_code == 200:
        intentos=4
        continuar=False
        try:
            data = response.json()
        except ValueError:
            print(f"No se pudo decodificar el JSON para el jugador {player}.")
    else:
        intentos=intentos+1
        print(f"Error al obtener datos para {player}: {response.status_code}.")
  return data

# Función para realizar la solicitud a la API y extraer los datos de Ana
def get_player_stats(player):
    data = get_player_data(player)
    campos_cero=0
    if data:

      # Campos de interés en heroes_comparisons
      attributes = [
          'time_played', 'games_won', 'win_percentage', 'weapon_accuracy_best_in_game',
          'eliminations_per_life', 'kill_streak_best', 'eliminations_avg_per_10_min',
          'deaths_avg_per_10_min', 'final_blows_avg_per_10_min', 'solo_kills_avg_per_10_min',
          'objective_kills_avg_per_10_min', 'objective_time_avg_per_10_min',
          'hero_damage_done_avg_per_10_min', 'healing_done_avg_per_10_min'
      ]

      # Campos adicionales de carrera para Ana
      additional_fields = [
          'scoped_accuracy_best_in_game', 'self_healing', 'self_healing_most_in_game',
          'enemies_slept', 'nano_boost_assists', 'unscoped_accuracy_best_in_game',
          'enemies_slept_most_in_game', 'nano_boost_assists_most_in_game',
          'biotic_grenade_kills'
      ]

      ana_stats = {}

      # Buscar los valores en heroes_comparisons
      heroes_comparisons = data['stats']['pc']['competitive']['heroes_comparisons']
      for attr in attributes:
        if attr in heroes_comparisons and heroes_comparisons[attr]:
            attr_values = heroes_comparisons[attr]['values']
            # Buscar el valor para el héroe 'ana'
            ana_data = next((item for item in attr_values if item['hero'] == 'ana'), None)
            ana_stats[attr] = ana_data['value'] if ana_data else None
        else:
            ana_stats[attr] = 0
            campos_cero=campos_cero+1

      # Buscar los valores en career_stats para Ana
      try:
        #print(player)
        if data['stats']['pc']['competitive']['career_stats']['ana']:
          career_stats = data['stats']['pc']['competitive']['career_stats'].get('ana', [{}])[0]
          # Extraer los campos adicionales
          for field in additional_fields:
              ana_stats[field] = next((stat['value'] for stat in career_stats.get('stats', []) if stat['key'] == field), None)
        else:
          #Si no hay datos específicos para el heroe se retorna None
          return None
      except KeyError as e:
          print(f"Error de clave en career_stats: {e}")
          #Si no hay datos específicos para el heroe se retorna None
          return None
      if campos_cero>10:
        #Si hay mas de 10 campos vacios de stats en general para el heroe se retorna None
        return None
      else:
        return ana_stats
    else:
      print(f"Perfil privado o datos no disponibles para {player}.")
      return None

# Lista de tiers a scrapear
tiers = ['bronze', 'silver', 'gold', 'platinum', 'diamond', 'master', 'grandmaster']
#tiers = ['diamond']

# Lista para almacenar todos los datos
all_data = []

# Iterar sobre cada tier y scrapear los datos
for tier in tiers:
    all_data.extend(scrape_tier_data(tier))

# Convertir la lista de datos en un DataFrame de pandas
df = pd.DataFrame(all_data, columns=['Player', 'Skill Tier'])

# Agregar las columnas para los atributos y los campos adicionales
attributes = [
    'time_played', 'games_won', 'win_percentage', 'weapon_accuracy_best_in_game',
    'eliminations_per_life', 'kill_streak_best', 'eliminations_avg_per_10_min',
    'deaths_avg_per_10_min', 'final_blows_avg_per_10_min', 'solo_kills_avg_per_10_min',
    'objective_kills_avg_per_10_min', 'objective_time_avg_per_10_min',
    'hero_damage_done_avg_per_10_min', 'healing_done_avg_per_10_min'
]
additional_fields = [
    'scoped_accuracy_best_in_game', 'self_healing', 'self_healing_most_in_game',
    'enemies_slept', 'nano_boost_assists', 'unscoped_accuracy_best_in_game',
    'enemies_slept_most_in_game', 'nano_boost_assists_most_in_game',
    'biotic_grenade_kills'
]

# Añadir columnas para los atributos y campos adicionales
all_columns = attributes + additional_fields
for column in all_columns:
    df[column] = None

# Iterar sobre cada jugador en el DataFrame y obtener sus estadísticas
for index, row in df.iterrows():
    player = row['Player']
    stats = get_player_stats(player)
    if stats is None:
      df.drop(index, inplace=True)
    else:
      for column, value in stats.items():
          if value is None:
            value=0
          if column in df.columns:
              df.at[index, column] = value

# Mostrar el DataFrame
print(df)
df.to_csv('/content/drive/MyDrive/Colab Notebooks/overbuff_ana_rankings_with_full_stats.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Error al obtener datos para Waifu#21504: 404.
# Error al obtener datos para Waifu#21504: 404.
# Error al obtener datos para Waifu#21504: 404.
# Perfil privado o datos no disponibles para Waifu#21504.
# Error al obtener datos para GrandmaSauce#11440: 404.
# Error al obtener datos para GrandmaSauce#11440: 404.
# Error al obtener datos para GrandmaSauce#11440: 404.
# Perfil privado o datos no disponibles para GrandmaSauce#11440.
# Error al obtener datos para Sage534#1371: 404.
# Error al obtener datos para Sage534#1371: 404.
# Error al obtener datos para Sage534#1371: 404.
# Perfil privado o datos no disponibles para Sage534#1371.
# Error al obtener datos para Eros#13990: 404.
# Error al obtener datos para Eros#13990: 404.
# Error al obtener datos para Eros#13990: 404.
# Perfil privado o datos no disponibles para Eros#13990.
# Error de clave en career_stats: 'ana'
# Error al obtener datos para RustEagle#24743: 404.
# Error al obtener datos para RustEagle#24743: 404.
# Error al obtener datos para RustEagle#24743: 404.
# Perfil privado o datos no disponibles para RustEagle#24743.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para Niko#12707: 404.
# Error al obtener datos para Niko#12707: 404.
# Error al obtener datos para Niko#12707: 404.
# Perfil privado o datos no disponibles para Niko#12707.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para iluxa#21608: 404.
# Error al obtener datos para iluxa#21608: 404.
# Error al obtener datos para iluxa#21608: 404.
# Perfil privado o datos no disponibles para iluxa#21608.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para Kuu#1375: 404.
# Error al obtener datos para Kuu#1375: 404.
# Error al obtener datos para Kuu#1375: 404.
# Perfil privado o datos no disponibles para Kuu#1375.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para Truther#11583: 404.
# Error al obtener datos para Truther#11583: 404.
# Error al obtener datos para Truther#11583: 404.
# Perfil privado o datos no disponibles para Truther#11583.
# Error de clave en career_stats: 'ana'
# Error al obtener datos para BigPapa#11375: 404.
# Error al obtener datos para BigPapa#11375: 404.
# Error al obtener datos para BigPapa#11375: 404.
# Perfil privado o datos no disponibles para BigPapa#11375.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para LaTe#21443: 404.
# Error al obtener datos para LaTe#21443: 404.
# Error al obtener datos para LaTe#21443: 404.
# Perfil privado o datos no disponibles para LaTe#21443.
# Error al obtener datos para DeadƗnsƗde#2940: 404.
# Error al obtener datos para DeadƗnsƗde#2940: 404.
# Error al obtener datos para DeadƗnsƗde#2940: 404.
# Perfil privado o datos no disponibles para DeadƗnsƗde#2940.
# Error al obtener datos para LargeToeNail#11735: 404.
# Error al obtener datos para LargeToeNail#11735: 404.
# Error al obtener datos para LargeToeNail#11735: 404.
# Perfil privado o datos no disponibles para LargeToeNail#11735.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para Amnas#1415: 404.
# Error al obtener datos para Amnas#1415: 404.
# Error al obtener datos para Amnas#1415: 404.
# Perfil privado o datos no disponibles para Amnas#1415.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para LiLiLiLiL#11189: 404.
# Error al obtener datos para LiLiLiLiL#11189: 404.
# Error al obtener datos para LiLiLiLiL#11189: 404.
# Perfil privado o datos no disponibles para LiLiLiLiL#11189.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para NoVoiceNChat#2687: 404.
# Error al obtener datos para NoVoiceNChat#2687: 404.
# Error al obtener datos para NoVoiceNChat#2687: 404.
# Perfil privado o datos no disponibles para NoVoiceNChat#2687.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para xaler#11242: 404.
# Error al obtener datos para xaler#11242: 404.
# Error al obtener datos para xaler#11242: 404.
# Perfil privado o datos no disponibles para xaler#11242.
# Error de clave en career_stats: 'ana'
# Error al obtener datos para Lukas#26758: 404.
# Error al obtener datos para Lukas#26758: 404.
# Error al obtener datos para Lukas#26758: 404.
# Perfil privado o datos no disponibles para Lukas#26758.
# Error al obtener datos para NoVoiceNChat#2687: 404.
# Error al obtener datos para NoVoiceNChat#2687: 404.
# Error al obtener datos para NoVoiceNChat#2687: 404.
# Perfil privado o datos no disponibles para NoVoiceNChat#2687.
# Error al obtener datos para Lemonade#11994: 404.
# Error al obtener datos para Lemonade#11994: 404.
# Error al obtener datos para Lemonade#11994: 404.
# Perfil privado o datos no disponibles para Lemonade#11994.
# Error de clave en career_stats: 'ana'
# Error al obtener datos para konnik#2185: 404.
# Error al obtener datos para konnik#2185: 404.
# Error al obtener datos para konnik#2185: 404.
# Perfil privado o datos no disponibles para konnik#2185.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para scootz44#1499: 404.
# Error al obtener datos para scootz44#1499: 404.
# Error al obtener datos para scootz44#1499: 404.
# Perfil privado o datos no disponibles para scootz44#1499.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para sizuku#31952: 404.
# Error al obtener datos para sizuku#31952: 404.
# Error al obtener datos para sizuku#31952: 404.
# Perfil privado o datos no disponibles para sizuku#31952.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para cynical#11664: 404.
# Error al obtener datos para cynical#11664: 404.
# Error al obtener datos para cynical#11664: 404.
# Perfil privado o datos no disponibles para cynical#11664.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para Twist01#11449: 404.
# Error al obtener datos para Twist01#11449: 404.
# Error al obtener datos para Twist01#11449: 404.
# Perfil privado o datos no disponibles para Twist01#11449.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para fogi#11629: 404.
# Error al obtener datos para fogi#11629: 404.
# Error al obtener datos para fogi#11629: 404.
# Perfil privado o datos no disponibles para fogi#11629.
# Error al obtener datos para SKY#29669: 404.
# Error al obtener datos para SKY#29669: 404.
# Error al obtener datos para SKY#29669: 404.
# Perfil privado o datos no disponibles para SKY#29669.
# Error al obtener datos para Inu#21179: 404.
# Error al obtener datos para Inu#21179: 404.
# Error al obtener datos para Inu#21179: 404.
# Perfil privado o datos no disponibles para Inu#21179.
# Error de clave en career_stats: 'ana'
# Error al obtener datos para esan#11589: 404.
# Error al obtener datos para esan#11589: 404.
# Error al obtener datos para esan#11589: 404.
# Perfil privado o datos no disponibles para esan#11589.
# Error al obtener datos para Aosya#2387: 404.
# Error al obtener datos para Aosya#2387: 404.
# Error al obtener datos para Aosya#2387: 404.
# Perfil privado o datos no disponibles para Aosya#2387.
# Error al obtener datos para Karhu#21382: 404.
# Error al obtener datos para Karhu#21382: 404.
# Error al obtener datos para Karhu#21382: 404.
# Perfil privado o datos no disponibles para Karhu#21382.
# Error al obtener datos para Tibiscuit#21694: 404.
# Error al obtener datos para Tibiscuit#21694: 404.
# Error al obtener datos para Tibiscuit#21694: 404.
# Perfil privado o datos no disponibles para Tibiscuit#21694.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para KarQ#1811: 404.
# Error al obtener datos para KarQ#1811: 404.
# Error al obtener datos para KarQ#1811: 404.
# Perfil privado o datos no disponibles para KarQ#1811.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para Vee#11952: 404.
# Error al obtener datos para Vee#11952: 404.
# Error al obtener datos para Vee#11952: 404.
# Perfil privado o datos no disponibles para Vee#11952.
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error de clave en career_stats: 'ana'
# Error al obtener datos para DouyuBecky#2220: 404.
# Error al obtener datos para DouyuBecky#2220: 404.
# Error al obtener datos para DouyuBecky#2220: 404.
# Perfil privado o datos no disponibles para DouyuBecky#2220.
# Error de clave en career_stats: 'ana'
#                 Player   Skill Tier time_played games_won win_percentage  \
# 0           PD22#11569       Bronze        6690         7             61
# 1    glorytrooper#1339       Bronze       51987        53             65
# 2    LucasTheVexd#1253       Bronze        1680         0              5
# 3            Poi#21548       Bronze        8759         9             61
# 4        benedryl#1748       Bronze        3793         1             21
# ..                 ...          ...         ...       ...            ...
# 694      Floomfie#1648  Grandmaster       20795        15             55
# 695       Scorch#11714  Grandmaster        6603         7             66
# 696       Lieven#11835  Grandmaster        4563         5             62
# 698       Jejudo#11437  Grandmaster         801         1            100
# 699         UnUm#21826  Grandmaster       20374        18             63
#
#     weapon_accuracy_best_in_game eliminations_per_life kill_streak_best  \
# 0                             24                  2.33               11
# 1                             49                  2.77               16
# 2                             29                     1                5
# 3                             25                  1.29                6
# 4                             38                  1.92                8
# ..                           ...                   ...              ...
# 694                           50                  1.45               10
# 695                           50                  1.73                9
# 696                           31                  1.38                7
# 698                           17                  2.14                7
# 699                           41                  1.42                8
#
#     eliminations_avg_per_10_min deaths_avg_per_10_min  ...  \
# 0                         12.56                  5.38  ...
# 1                         13.25                  4.78  ...
# 2                          9.29                  9.29  ...
# 3                          9.45                  7.33  ...
# 4                         10.92                  5.69  ...
# ..                          ...                   ...  ...
# 694                        8.54                  5.89  ...
# 695                        9.45                  5.45  ...
# 696                        8.15                  5.92  ...
# 698                       11.24                  5.24  ...
# 699                        7.27                  5.12  ...
#
#     healing_done_avg_per_10_min scoped_accuracy_best_in_game self_healing  \
# 0                          6287                           86         2004
# 1                          6208                          100         8347
# 2                          5352                           50         1329
# 3                          6657                          100         1508
# 4                          6903                           69         1907
# ..                          ...                          ...          ...
# 694                        9272                           82        10880
# 695                        7723                           73         2029
# 696                        8988                           81         2395
# 698                       10000                           69          435
# 699                        8909                           80        10259
#
#     self_healing_most_in_game enemies_slept nano_boost_assists  \
# 0                         335            72                 37
# 1                         391           589                228
# 2                         606            25                  0
# 3                         385            88                 25
# 4                         585            35                 12
# ..                        ...           ...                ...
# 694                       731           164                100
# 695                       558            40                 24
# 696                       476            42                 30
# 698                       435             9                  6
# 699                       982           143                 77
#
#     unscoped_accuracy_best_in_game enemies_slept_most_in_game  \
# 0                               57                         10
# 1                               76                         17
# 2                               57                          8
# 3                               51                         12
# 4                               65                         11
# ..                             ...                        ...
# 694                            120                         12
# 695                             64                          4
# 696                             68                         12
# 698                             51                          9
# 699                             77                          9
#
#     nano_boost_assists_most_in_game biotic_grenade_kills
# 0                                11                   71
# 1                                10                  512
# 2                                 0                   13
# 3                                 5                   87
# 4                                 4                   30
# ..                              ...                  ...
# 694                               8                  134
# 695                               4                   42
# 696                               8                   28
# 698                               6                    7
# 699                               7                  100
#
# [597 rows x 25 columns]
